# %% [markdown]
# <a href="https://colab.research.google.com/github/TapasKumarDutta1/Manga_translation/blob/main/working_example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/facebookresearch/detr.git   #cloning github repo of detr to import its unique loss
# Out:
# Cloning into 'detr'...
# remote: Enumerating objects: 263, done.
# remote: Total 263 (delta 0), reused 0 (delta 0), pack-reused 263
# Receiving objects: 100% (263/263), 12.88 MiB | 31.17 MiB/s, done.
# Resolving deltas: 100% (122/122), done.

# %%
# !git clone https://github.com/TapasKumarDutta1/Transformer-pytorch.git
# Out:
# Cloning into 'Transformer-pytorch'...
# remote: Enumerating objects: 346, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 346 (delta 16), reused 5 (delta 5), pack-reused 325
# Receiving objects: 100% (346/346), 6.60 MiB | 27.57 MiB/s, done.
# Resolving deltas: 100% (144/144), done.

# %%
# !git clone https://github.com/TapasKumarDutta1/Manga_translation.git
# Out:
# Cloning into 'Manga_translation'...
# remote: Enumerating objects: 179, done.
# remote: Counting objects: 100% (83/83), done.
# remote: Compressing objects: 100% (72/72), done.
# remote: Total 179 (delta 39), reused 0 (delta 0), pack-reused 96
# Receiving objects: 100% (179/179), 1.09 MiB | 16.18 MiB/s, done.
# Resolving deltas: 100% (75/75), done.

# %%
cd /content/Manga_translation
# Out:
# /content/Manga_translation

# %%
pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.2/521.2 kB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.2/64.2 kB 9.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 79.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.7/71.7 MB 12.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 600.9/600.9 kB 27.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 73.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 67.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 15.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 65.4 MB/s eta 0:00:00
# ...

# %%
cd ..
# Out:
# /content

# %%
# !gdown 1axXoQk6nh8AtInRd1V__Hg0mak5gzg52
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1axXoQk6nh8AtInRd1V__Hg0mak5gzg52
# To: /content/detr_best.zip
# 100% 155M/155M [00:02<00:00, 52.2MB/s]

# %%
# !gdown 1VIqAXQ135or6PghILrXkHb1j4IYNAz79
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1VIqAXQ135or6PghILrXkHb1j4IYNAz79
# To: /content/ocr.zip
# 100% 2.26G/2.26G [00:30<00:00, 74.0MB/s]

# %%
# !gdown 1Bvq3eoNopEcNKfAQNXCm0iC_GS9ptKZw
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1Bvq3eoNopEcNKfAQNXCm0iC_GS9ptKZw
# To: /content/eni.npy
# 100% 35.2M/35.2M [00:00<00:00, 75.7MB/s]

# %%
# !gdown 1GWYm1Z1CmnvlJgRWdBk0mVnHi5gdFrkO
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1GWYm1Z1CmnvlJgRWdBk0mVnHi5gdFrkO
# To: /content/ens.npy
# 100% 6.65M/6.65M [00:00<00:00, 29.4MB/s]

# %%
# !gdown 1ckI_40gtzscLyfsyzSl2AHSGBAN7CGSV
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ckI_40gtzscLyfsyzSl2AHSGBAN7CGSV
# To: /content/jps.npy
# 100% 5.40M/5.40M [00:00<00:00, 63.5MB/s]

# %%
# !gdown 13DJy7KX4seYNFfnvTj6smo_McFh0u4On
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=13DJy7KX4seYNFfnvTj6smo_McFh0u4On
# To: /content/weights.hdf5
# 100% 1.06G/1.06G [00:07<00:00, 134MB/s]

# %%
# !gdown 1EixYngMXRQ8JdwH5Xc4stoRzIbLgBPq7
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1EixYngMXRQ8JdwH5Xc4stoRzIbLgBPq7
# To: /content/TaQPrNmh_0511220618251gpadd.jpeg
# 100% 2.09M/2.09M [00:00<00:00, 207MB/s]

# %%
# !gdown 1g3HXlepDjjyRYUMYg6YBEae4POP_r3lv
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1g3HXlepDjjyRYUMYg6YBEae4POP_r3lv
# To: /content/weights_pretrained.hdf5
# 100% 608M/608M [00:06<00:00, 89.4MB/s]

# %%
# !unzip /content/detr_best.zip
# Out:
# Archive:  /content/detr_best.zip
#   inflating: detr_best_0 (1).pth

# %%
import os
from zipfile import ZipFile
os.environ["WANDB_DISABLED"] = "true"
try:
    os.mkdir("checkpoint")
except:
    pass
try:
    os.mkdir("detected")
except:
    pass
with ZipFile("/content/ocr.zip", "r") as zObject:
    zObject.extractall(path="/content/checkpoint")

# %% [markdown]
# ## Detect

# %%
import sys
sys.path.append("/content/Manga_translation/src/inference")

# %%
from detection import detect
coords = detect("/content/TaQPrNmh_0511220618251gpadd.jpeg")
# Out:
# Downloading: "https://github.com/facebookresearch/detr/zipball/main" to /root/.cache/torch/hub/main.zip
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:01<00:00, 67.8MB/s]
# ...

# %% [markdown]
# ## Recognize

# %%
from convert import detect_and_translate
detect_and_translate(coords)
# Out:
# tokenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/104 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/479 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/258k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/491 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/24.7k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/69.2k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/228 [00:00<?, ?B/s]
# Could not find image processor class in the image processor config or the model config. Loading based on pattern matching with the model's feature extractor configuration.
# tokenizer_config.json:   0%|          | 0.00/1.12k [00:00<?, ?B/s]
# ...
